# %% [markdown]
# # Assignment 2 — Alternative Measures of Volatility
#
#
# **Student:** YOUR NAME HERE
# **Course:** Machine Learning in Finance and Macroeconomics
# **Submission:** Submit the completed `.ipynb` notebook.
#
# ### Instructions
#
# 1. Complete every **Core Exercise**.
# 2. Keep the question text in the notebook.
# 3. Put code in the designated code cells and short explanations in the designated Markdown cells.
# 4. Before submitting, use **Restart Kernel and Run All Cells**.
# 5. Make sure all requested tables and figures appear in the saved notebook.
# 6. The notebook should run from top to bottom without relying on variables from another notebook.
# 7. Use one of the stock indices such as Dow Jones or Nasdaq, so we can compare your results with the SP500.
#
# **Suggested filename:** `Lastname_Firstname_ClassXX_Assignment.ipynb`

# %% [markdown]
# ## Setup

# %%
# %pip install yfinance statsmodels scikit-learn

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import course_tools_general as ctg

from scipy.stats import skew, kurtosis, jarque_bera, norm
import statsmodels.formula.api as smf
dji = ctg.load_prices(ticker="^DJI", start="1990-01-01")
dji.head()


for col in ["Open", "High", "Low", "Close"]:
    dji[col] = dji[col].where(dji[col] > 0, np.nan)

dji[["Open", "High", "Low", "Close"]] = dji[
    ["Open", "High", "Low", "Close"]
].ffill()

dji["Log_Close"] = np.log(dji["Close"])
dji["Return"] = dji["Log_Close"].diff()

print(dji[["Close", "Return"]].head())
print("Sample:", dji.index.min().date(), "to", dji.index.max().date())
# Out:
# Price             Close    Return
# Date
# 1992-01-02  3172.399902       NaN
# 1992-01-03  3201.500000  0.009131
# 1992-01-06  3200.100098 -0.000437
# 1992-01-07  3204.800049  0.001468
# 1992-01-08  3203.899902 -0.000281
# Sample: 1992-01-02 to 2026-08-28

# %% [markdown]
# ## Core Exercise 1 — Garman–Klass range volatility
#
# Using
#
# $
# HL_t=\log(H_t/L_t), \qquad CO_t=\log(C_t/O_t),
# $
#
# construct the Garman–Klass variance measure
#
# $
# GK_t = \tfrac12 HL_t^2-(2\log 2-1)CO_t^2.
# $
#
# 1. Construct 10-day and 20-day rolling GK volatility.
# 2. Plot both series.
# 3. Report their correlation.
#
# **Question:** What is the effect of increasing the rolling window from 10 to 20 days?

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Your interpretation
#
# *Replace this text with a short answer.*

# %% [markdown]
# ## Core Exercise 2 — OK range volatility
#
# Construct the class measure
#
# $
# OK_t = 0.811\,HL_t^2 - 0.369\,CO_t^2.
# $
#
# 1. Compute the 20-day rolling OK volatility.
# 2. Plot GK-20 and OK-20 on the same graph.
# 3. Report their correlation and the ratio of their sample means.
#
# **Question:** Are these two range measures conveying substantially different information?

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Your interpretation
#
# *Replace this text with a short answer.*

# %% [markdown]
# ## Core Exercise 3 — Range volatility versus close-to-close volatility
#
# 1. Compute the 20-day rolling standard deviation of daily close-to-close log returns.
# 2. Combine it with GK-20 and OK-20 in one DataFrame.
# 3. Normalize each series to the interval \([0,1]\) with `MinMaxScaler`.
# 4. Plot all three normalized series.
#
# **Question:** During high-volatility periods, do the measures move together? Identify one period in which they differ noticeably.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Your interpretation
#
# *Replace this text with a short answer.*

# %% [markdown]
# ## Core Exercise 4 — A simple out-of-sample return regression
#
# Using five lagged daily returns as predictors:
#
# 1. Construct an \(X\) matrix containing \(r_{t-1},\ldots,r_{t-5}\).
# 2. Use the first 80% of observations for training and the final 20% for testing. **Do not shuffle the data.**
# 3. Estimate OLS on the training sample.
# 4. Report training and test MSE.
#
# **Question:** Does the lagged-return model have useful out-of-sample predictive power? Explain using the test MSE and the economic difficulty of forecasting daily returns.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Your interpretation
#
# *Replace this text with a short answer.*

# %% [markdown]
# ## Optional Extension
#
# Add GK-20 and OK-20 as additional predictors, taking care to align dates and avoid using future information. Does the out-of-sample MSE improve?

# %%
# OPTIONAL CODE HERE

# %% [markdown]
# ## Submission checklist
#
# - [ ] All four core exercises completed
# - [ ] Time ordering preserved in the train/test split
# - [ ] All figures and MSE results visible
# - [ ] Interpretation questions answered
# - [ ] Restarted kernel and ran all cells successfully
