# %% [markdown]
# # Assignment 1 — Returns, Volatility, and Downside Risk
#
#
# **Student:** YOUR NAME HERE
# **Course:** Machine Learning in Finance and Macroeconomics
# **Submission:** Submit the completed `.ipynb` notebook.
#
# ### Instructions
#
# 1. Complete every **Core Exercise**.
# 2. Keep the question text in the notebook.
# 3. Put code in the designated code cells and short explanations in the designated Markdown cells.
# 4. Before submitting, use **Restart Kernel and Run All Cells**.
# 5. Make sure all requested tables and figures appear in the saved notebook.
# 6. The notebook should run from top to bottom without relying on variables from another notebook.
# 7. Unless an exercise says otherwise, use the S&P 500 data downloaded in the Setup section.
#
# **Suggested filename:** `GroupNames_Class #_Assignment.ipynb`

# %% [markdown]
# ## Setup
#
# This previous Lecture 1 uses daily S&P 500 data. We begin in 1990 to keep the download and calculations reasonably quick.
# Try another stock index, suh as the Dow Jones (^DJI) or the Nasdaq Compositie (^IXIC).

# %%
# %pip install yfinance scipy statsmodels

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import course_tools_general as ctg

from scipy.stats import skew, kurtosis, jarque_bera, norm
import statsmodels.formula.api as smf
dji = ctg.load_prices(ticker="^DJI", start="1990-01-01")
dji.head()


for col in ["Open", "High", "Low", "Close"]:
    dji[col] = dji[col].where(dji[col] > 0, np.nan)

dji[["Open", "High", "Low", "Close"]] = dji[
    ["Open", "High", "Low", "Close"]
].ffill()

dji["Log_Close"] = np.log(dji["Close"])
dji["Return"] = dji["Log_Close"].diff()

print(dji[["Close", "Return"]].head())
print("Sample:", dji.index.min().date(), "to", dji.index.max().date())
# Out:
# Price             Close    Return
# Date
# 1992-01-02  3172.399902       NaN
# 1992-01-03  3201.500000  0.009131
# 1992-01-06  3200.100098 -0.000437
# 1992-01-07  3204.800049  0.001468
# 1992-01-08  3203.899902 -0.000281
# Sample: 1992-01-02 to 2026-08-28

# %% [markdown]
# ## Core Exercise 1 — The return distribution
#
# Using `dji["Return"]`:
#
# 1. Compute the mean, standard deviation, skewness, kurtosis (normal = 3), and Jarque–Bera p-value.
# 2. Display the results in a small DataFrame.
# 3. Plot a histogram of returns with a fitted normal density overlaid.
#
# **Question:** Based on your statistics and figure, does a normal distribution appear to describe daily returns well? Give two reasons.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Your interpretation
#
# *Replace this text with a short answer.*

# %% [markdown]
# ## Core Exercise 2 — Historical volatility
#
# 1. Compute 20-day rolling historical volatility from daily log returns.
# 2. Plot it through time.
# 3. Find the five dates with the largest 20-day volatility.
#
# **Question:** Do the largest observations appear to occur in isolated days or in clusters? What does this suggest about volatility?

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Your interpretation
#
# *Replace this text with a short answer.*

# %% [markdown]
# ## Core Exercise 3 — Historical versus normal downside risk
#
# Using a 252-trading-day window:
#
# 1. Compute the rolling historical 5% return quantile.
# 2. Compute the rolling normal 5% return quantile using the rolling mean and standard deviation.
# 3. Plot the two series on the same graph.
# 4. Compute the average difference between the historical and normal thresholds.
#
# **Question:** Which method generally produces the more negative downside threshold? What does that tell you about tail risk?

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Your interpretation
#
# *Replace this text with a short answer.*

# %% [markdown]
# ## Core Exercise 4 — Quantile regression and downside risk
#
# Construct the same timing used in class:
#
# $
# r_{t+1} = f(\sigma_t),
# $
#
# where `volatility_today_pct` is the 20-day rolling volatility known at time \(t\).
#
# Estimate:
#
# - OLS for the conditional mean,
# - quantile regression at \(q=0.50\),
# - quantile regression at \(q=0.05\).
#
# Put the volatility coefficient and p-value from all three models in one table.
#
# **Question:** Is the relationship between volatility and the lower 5% return quantile different from the relationship between volatility and the conditional mean?

# %%
# Starter structure
qr_data = pd.DataFrame(index=spx.index)
qr_data["return_next_pct"] = 100 * spx["Return"].shift(-1)
qr_data["volatility_today_pct"] = 100 * spx["Return"].rolling(20).std()
qr_data = qr_data.dropna()

# YOUR CODE HERE: estimate OLS, q=.50, and q=.05 models

# %% [markdown]
# ### Your interpretation
#
# *Replace this text with a short answer.*

# %% [markdown]
# ## Optional Extension
#
# Repeat the downside quantile regression at \(q=0.01\). Compare the volatility coefficient with the \(q=0.05\) result. Does the volatility effect become stronger deeper in the lower tail?

# %%
# OPTIONAL CODE HERE

# %% [markdown]
# ## Submission checklist
#
# - [ ] All four core exercises completed
# - [ ] All requested figures visible
# - [ ] All interpretation questions answered
# - [ ] Restarted kernel and ran all cells successfully
# - [ ] Saved notebook with your name in the filename
